# %%
import random
from dataclasses import replace

from pathlib import Path
import sys

cwd = Path.cwd()
for root in [cwd, *cwd.parents]:
    src_path = root / 'src'
    if (src_path / 'replenishment').exists():
        sys.path.insert(0, str(src_path))
        break
    src_path = root / 'replenishment' / 'src'
    if (src_path / 'replenishment').exists():
        sys.path.insert(0, str(src_path))
        break

for name in list(sys.modules):
    if name == 'replenishment' or name.startswith('replenishment.'):
        del sys.modules[name]

# %%
import time
from collections import Counter

from replenishment import ForecastCandidatesConfig, optimize_forecast_targets, optimize_aggregation_and_forecast_targets

# %%
article_count = 50_000
periods = 120
lead_time = 1
holding_cost_per_unit = 0.8
stockout_cost_per_unit = 3.5

base_demand = [50 + (idx % 10) for idx in range(periods)]
percentile_targets = list(range(10, 85, 5))

def _percentile_offset(target: int) -> int:
    return int(round((target - 50) / 5))

forecast_candidates = {
    f"p{target}": [value + _percentile_offset(target) for value in base_demand]
    for target in percentile_targets
}

candidate_configs = {
    f'article-{idx:05d}': ForecastCandidatesConfig(
        periods=periods,
        demand=base_demand,
        initial_on_hand=40,
        lead_time=lead_time,
        forecast_candidates=forecast_candidates,
        holding_cost_per_unit=holding_cost_per_unit,
        stockout_cost_per_unit=stockout_cost_per_unit,
    )
    for idx in range(article_count)
}

# %%
start = time.perf_counter()
candidate_windows = list(range(1, 11))
optimized_targets = optimize_aggregation_and_forecast_targets(
    candidate_configs,
    candidate_windows=candidate_windows,
)
elapsed = time.perf_counter() - start

print(f'Total time: {elapsed:.2f}s')
print(f'Time per article: {elapsed / article_count:.6f}s')

target_counts = Counter(result.target for result in optimized_targets.values())
print(dict(target_counts))
# Out:
# Total time: 603.19s
# Time per article: 0.012064s
# {'p55': 50000}

# %%
optimized_targets['article-00000']
# Out:
# AggregationForecastTargetOptimizationResult(window=2, target='p55', policy=PercentileForecastOptimizationPolicy(forecast=[103, 107, 111, 115, 119, 103, 107, 111, 115, 119, 103, 107, 111, 115, 119, 103, 107, 111, 115, 119, 103, 107, 111, 115, 119, 103, 107, 111, 115, 119, 103, 107, 111, 115, 119, 103, 107, 111, 115, 119, 103, 107, 111, 115, 119, 103, 107, 111, 115, 119, 103, 107, 111, 115, 119, 103, 107, 111, 115, 119], lead_time=1), simulation=SimulationResult(snapshots=[InventorySnapshot(period=0, starting_on_hand=40, demand=101, received=0, ending_on_hand=0, backorders=61, order_placed=107, on_order=107), InventorySnapshot(period=1, starting_on_hand=46, demand=105, received=107, ending_on_hand=0, backorders=59, order_placed=111, on_order=111), InventorySnapshot(period=2, starting_on_hand=52, demand=109, received=111, ending_on_hand=0, backorders=57, order_placed=115, on_order=115), InventorySnapshot(period=3, starting_on_hand=58, demand=113, received=115, ending_on_hand=0, backorders=55, order_placed=119, on_order=119), InventorySnapshot(period=4, starting_on_hand=64, demand=117, received=119, ending_on_hand=0, backorders=53, order_placed=103, on_order=103), InventorySnapshot(period=5, starting_on_hand=50, demand=101, received=103, ending_on_hand=0, backorders=51, order_placed=107, on_order=107), InventorySnapshot(period=6, starting_on_hand=56, demand=105, received=107, ending_on_hand=0, backorders=49, order_placed=111, on_order=111), InventorySnapshot(period=7, starting_on_hand=62, demand=109, received=111, ending_on_hand=0, backorders=47, order_placed=115, on_order=115), InventorySnapshot(period=8, starting_on_hand=68, demand=113, received=115, ending_on_hand=0, backorders=45, order_placed=119, on_order=119), InventorySnapshot(period=9, starting_on_hand=74, demand=117, received=119, ending_on_hand=0, backorders=43, order_placed=103, on_order=103), InventorySnapshot(period=10, starting_on_hand=60, demand=101, received=103, ending_on_hand=0, backorders=41, order_placed=107, on_order=107), InventorySnapshot(period=11, starting_on_hand=66, demand=105, received=107, ending_on_hand=0, backorders=39, order_placed=111, on_order=111), InventorySnapshot(period=12, starting_on_hand=72, demand=109, received=111, ending_on_hand=0, backorders=37, order_placed=115, on_order=115), InventorySnapshot(period=13, starting_on_hand=78, demand=113, received=115, ending_on_hand=0, backorders=35, order_placed=119, on_order=119), InventorySnapshot(period=14, starting_on_hand=84, demand=117, received=119, ending_on_hand=0, backorders=33, order_placed=103, on_order=103), InventorySnapshot(period=15, starting_on_hand=70, demand=101, received=103, ending_on_hand=0, backorders=31, order_placed=107, on_order=107), InventorySnapshot(period=16, starting_on_hand=76, demand=105, received=107, ending_on_hand=0, backorders=29, order_placed=111, on_order=111), InventorySnapshot(period=17, starting_on_hand=82, demand=109, received=111, ending_on_hand=0, backorders=27, order_placed=115, on_order=115), InventorySnapshot(period=18, starting_on_hand=88, demand=113, received=115, ending_on_hand=0, backorders=25, order_placed=119, on_order=119), InventorySnapshot(period=19, starting_on_hand=94, demand=117, received=119, ending_on_hand=0, backorders=23, order_placed=103, on_order=103), InventorySnapshot(period=20, starting_on_hand=80, demand=101, received=103, ending_on_hand=0, backorders=21, order_placed=107, on_order=107), InventorySnapshot(period=21, starting_on_hand=86, demand=105, received=107, ending_on_hand=0, backorders=19, order_placed=111, on_order=111), InventorySnapshot(period=22, starting_on_hand=92, demand=109, received=111, ending_on_hand=0, backorders=17, order_placed=115, on_order=115), InventorySnapshot(period=23, starting_on_hand=98, demand=113, received=115, ending_on_hand=0, backorders=15, order_placed=119, on_order=119), InventorySnapshot(period=24, starting_on_hand=104, demand=117, received=119, ending_on_hand=0, backorders=13, order_placed=103,  ...

# %%
{article_id: result.target for article_id, result in optimized_targets.items()}
# Out:
# {'article-00000': 'p55',
#  'article-00001': 'p55',
#  'article-00002': 'p55',
#  'article-00003': 'p55',
#  'article-00004': 'p55',
#  'article-00005': 'p55',
#  'article-00006': 'p55',
#  'article-00007': 'p55',
#  'article-00008': 'p55',
#  'article-00009': 'p55',
#  'article-00010': 'p55',
#  'article-00011': 'p55',
#  'article-00012': 'p55',
#  'article-00013': 'p55',
#  'article-00014': 'p55',
#  'article-00015': 'p55',
#  'article-00016': 'p55',
#  'article-00017': 'p55',
#  'article-00018': 'p55',
#  'article-00019': 'p55',
#  'article-00020': 'p55',
#  'article-00021': 'p55',
#  'article-00022': 'p55',
#  'article-00023': 'p55',
#  'article-00024': 'p55',
#  'article-00025': 'p55',
#  'article-00026': 'p55',
#  'article-00027': 'p55',
#  'article-00028': 'p55',
#  'article-00029': 'p55',
#  'article-00030': 'p55',
#  'article-00031': 'p55',
#  'article-00032': 'p55',
#  'article-00033': 'p55',
#  'article-00034': 'p55',
#  'article-00035': 'p55',
#  'article-00036': 'p55',
#  'article-00037': 'p55',
#  'article-00038': 'p55',
#  'article-00039': 'p55',
#  'article-00040': 'p55',
#  'article-00041': 'p55',
#  'article-00042': 'p55',
#  'article-00043': 'p55',
#  'article-00044': 'p55',
#  'article-00045': 'p55',
#  'article-00046': 'p55',
#  'article-00047': 'p55',
#  'article-00048': 'p55',
#  'article-00049': 'p55',
#  'article-00050': 'p55',
#  'article-00051': 'p55',
#  'article-00052': 'p55',
#  'article-00053': 'p55',
#  'article-00054': 'p55',
#  'article-00055': 'p55',
#  'article-00056': 'p55',
#  'article-00057': 'p55',
#  'article-00058': 'p55',
#  'article-00059': 'p55',
#  'article-00060': 'p55',
#  'article-00061': 'p55',
#  'article-00062': 'p55',
#  'article-00063': 'p55',
#  'article-00064': 'p55',
#  'article-00065': 'p55',
#  'article-00066': 'p55',
#  'article-00067': 'p55',
#  'article-00068': 'p55',
#  'article-00069': 'p55',
#  'article-00070': 'p55',
#  'article-00071': 'p55',
#  'article-00072': 'p55',
#  'article-00073': 'p55',
#  'article-00074': 'p55',
#  'article-00075': 'p55',
#  'article-00076': 'p55',
#  'article-00077': 'p55',
#  'article-00078': 'p55',
#  'article-00079': 'p55',
#  'article-00080': 'p55',
#  'article-00081': 'p55',
#  'article-00082': 'p55',
#  'article-00083': 'p55',
#  'article-00084': 'p55',
#  'article-00085': 'p55',
#  'article-00086': 'p55',
#  'article-00087': 'p55',
#  'article-00088': 'p55',
#  'article-00089': 'p55',
#  'article-00090': 'p55',
#  'article-00091': 'p55',
#  'article-00092': 'p55',
#  'article-00093': 'p55',
#  'article-00094': 'p55',
#  'article-00095': 'p55',
#  'article-00096': 'p55',
#  'article-00097': 'p55',
#  'article-00098': 'p55',
#  'article-00099': 'p55',
#  'article-00100': 'p55',
#  'article-00101': 'p55',
#  'article-00102': 'p55',
#  'article-00103': 'p55',
#  'article-00104': 'p55',
#  'article-00105': 'p55',
#  'article-00106': 'p55',
#  'article-00107': 'p55',
#  'article-00108': 'p55',
#  'article-00109': 'p55',
#  'article-00110': 'p55',
#  'article-00111': 'p55',
#  'article-00112': 'p55',
#  'article-00113': 'p55',
#  'article-00114': 'p55',
#  'article-00115': 'p55',
#  'article-00116': 'p55',
#  'article-00117': 'p55',
#  'article-00118': 'p55',
#  'article-00119': 'p55',
#  'article-00120': 'p55',
#  'article-00121': 'p55',
#  'article-00122': 'p55',
#  'article-00123': 'p55',
#  'article-00124': 'p55',
#  'article-00125': 'p55',
#  'article-00126': 'p55',
#  'article-00127': 'p55',
#  'article-00128': 'p55',
#  'article-00129': 'p55',
#  'article-00130': 'p55',
#  'article-00131': 'p55',
#  'article-00132': 'p55',
#  'article-00133': 'p55',
#  'article-00134': 'p55',
#  'article-00135': 'p55',
#  'article-00136': 'p55',
#  'article-00137': 'p55',
#  'article-00138': 'p55',
#  'article-00139': 'p55',
#  'article-00140': 'p55',
#  'article-00141': 'p55',
#  'article-00142': 'p55',
#  'article-00143': 'p55',
#  'article-00144': 'p55',
#  'article-00145': 'p55',
#  'article-00146': 'p55',
#  'article-00147': 'p55',
#  'article-00148': 'p55',
#  'article-00149': 'p55',
#  'article-00150': 'p55',
#  'article-00151': 'p55',
#  'article-00152': 'p55',
#  'article-00153': 'p55',
#  'article-00154': 'p55',
#  'article-00155': 'p55',
#  'article-00156': 'p55',
#  'article-00157': 'p55',
#  'article-00158': 'p55',
#  'article-00159': 'p55',
#  'article-00160': 'p55',
#  'article-00161': 'p55',
#  'article-00162': 'p55',
#  'article-00163': 'p55',
#  'article-00164': 'p55',
#  'article-00165': 'p55',
#  'article-00166': 'p55',
#  'article-00167': 'p55',
#  'article-00168': 'p55',
#  'article-00169': 'p55',
#  'article-00170': 'p55',
#  'article-00171': 'p55',
#  'article-00172': 'p55',
#  'article-00173': 'p55',
#  'article-00174': 'p55',
#  'article-00175': 'p55',
#  'article-00176': 'p55',
#  'article-00177': 'p55',
#  'article-00178': 'p55',
#  'article-00179': 'p55',
#  'article-00180': 'p55',
#  'article-00181': 'p55',
#  'article-00182': 'p55',
#  'article-00183': 'p55',
#  'article-00184': 'p55',
#  'article-00185': 'p55',
#  'article-00186': 'p55',
#  'article-00187': 'p55',
#  'article-00188': 'p55',
#  'article-00189': 'p55',
#  'article-00190': 'p55',
#  'article-00191': 'p55',
#  'article-00192': 'p55',
#  'article-00193': 'p55',
#  'article-00194': 'p55',
#  'article-00195': 'p55',
#  'article-00196': 'p55',
#  'article-00197': 'p55',
#  'article-00198': 'p55',
#  'article-00199': 'p55',
#  'article-00200': 'p55',
#  'article-00201': 'p55',
#  'article-00202': 'p55',
#  'article-00203': 'p55',
#  'article-00204': 'p55',
#  'article-00205': 'p55',
#  'article-00206': 'p55',
#  'article-00207': 'p55',
#  'article-00208': 'p55',
#  'article-00209': 'p55',
#  'article-00210': 'p55',
#  'article-00211': 'p55',
#  'article-00212': 'p55',
#  'article-00213': 'p55',
#  'article-00214': 'p55',
#  'article-00215': 'p55',
#  'article-00216': 'p55',
#  'article-00217': 'p55',
#  'article-00218': 'p55',
#  'article-00219': 'p55',
#  'article-00220': 'p55',
#  'article-00221': 'p55',
#  'article-00222': 'p55',
#  'article-00223': 'p55',
#  'article-00224': 'p55',
#  'article-00225': 'p55',
#  'article-00226': 'p55',
#  'article-00227': 'p55',
#  'article-00228': 'p55',
#  'article-00229': 'p55',
#  'article-00230': 'p55',
#  'article-00231': 'p55',
#  'article-00232': 'p55',
#  'article-00233': 'p55',
#  'article-00234': 'p55',
#  'article-00235': 'p55',
#  'article-00236': 'p55',
#  'article-00237': 'p55',
#  'article-00238': 'p55',
#  'article-00239': 'p55',
#  'article-00240': 'p55',
#  'article-00241': 'p55',
#  'article-00242': 'p55',
#  'article-00243': 'p55',
#  'article-00244': 'p55',
#  'article-00245': 'p55',
#  'article-00246': 'p55',
#  'article-00247': 'p55',
#  'article-00248': 'p55',
#  'article-00249': 'p55',
#  'article-00250': 'p55',
#  'article-00251': 'p55',
#  'article-00252': 'p55',
#  'article-00253': 'p55',
#  'article-00254': 'p55',
#  'article-00255': 'p55',
#  'article-00256': 'p55',
#  'article-00257': 'p55',
#  'article-00258': 'p55',
#  'article-00259': 'p55',
#  'article-00260': 'p55',
#  'article-00261': 'p55',
#  'article-00262': 'p55',
#  'article-00263': 'p55',
#  'article-00264': 'p55',
#  'article-00265': 'p55',
#  'article-00266': 'p55',
#  'article-00267': 'p55',
#  'article-00268': 'p55',
#  'article-00269': 'p55',
#  'article-00270': 'p55',
#  'article-00271': 'p55',
#  'article-00272': 'p55',
#  'article-00273': 'p55',
#  'article-00274': 'p55',
#  'article-00275': 'p55',
#  'article-00276': 'p55',
#  'article-00277': 'p55',
#  'article-00278': 'p55',
#  'article-00279': 'p55',
#  'article-00280': 'p55',
#  'article-00281': 'p55',
#  'article-00282': 'p55',
#  'article-00283': 'p55',
#  'article-00284': 'p55',
#  'article-00285': 'p55',
#  'article-00286': 'p55',
#  'article-00287': 'p55',
#  'article-00288': 'p55',
#  'article-00289': 'p55',
#  'article-00290': 'p55',
#  'article-00291': 'p55',
#  'article-00292': 'p55',
#  'article-00293': 'p55',
#  'article-00294': 'p55',
#  'article-00295': 'p55',
#  'article-00296': 'p55',
#  'article-00297': 'p55',
#  'article-00298': 'p55',
#  'article-00299': 'p55',
#  'article-00300': 'p55',
#  'article-00301': 'p55',
#  'article-00302': 'p55',
#  'article-00303': 'p55',
#  'article-00304': 'p55',
#  'article-00305': 'p55',
#  'article-00306': 'p55',
#  'article-00307': 'p55',
#  'article-00308': 'p55',
#  'article-00309': 'p55',
#  'article-00310': 'p55',
#  'article-00311': 'p55',
#  'article-00312': 'p55',
#  'article-00313': 'p55',
#  'article-00314': 'p55',
#  'article-00315': 'p55',
#  'article-00316': 'p55',
#  'article-00317': 'p55',
#  'article-00318': 'p55',
#  'article-00319': 'p55',
#  'article-00320': 'p55',
#  'article-00321': 'p55',
#  'article-00322': 'p55',
#  'article-00323': 'p55',
#  'article-00324': 'p55',
#  'article-00325': 'p55',
#  'article-00326': 'p55',
#  'article-00327': 'p55',
#  'article-00328': 'p55',
#  'article-00329': 'p55',
#  'article-00330': 'p55',
#  'article-00331': 'p55',
#  'article-00332': 'p55',
#  'article-00333': 'p55',
#  'article-00334': 'p55',
#  'article-00335': 'p55',
#  'article-00336': 'p55',
#  'article-00337': 'p55',
#  'article-00338': 'p55',
#  'article-00339': 'p55',
#  'article-00340': 'p55',
#  'article-00341': 'p55',
#  'article-00342': 'p55',
#  'article-00343': 'p55',
#  'article-00344': 'p55',
#  'article-00345': 'p55',
#  'article-00346': 'p55',
#  'article-00347': 'p55',
#  'article-00348': 'p55',
#  'article-00349': 'p55',
#  'article-00350': 'p55',
#  'article-00351': 'p55',
#  'article-00352': 'p55',
#  'article-00353': 'p55',
#  'article-00354': 'p55',
#  'article-00355': 'p55',
#  'article-00356': 'p55',
#  'article-00357': 'p55',
#  'article-00358': 'p55',
#  'article-00359': 'p55',
#  'article-00360': 'p55',
#  'article-00361': 'p55',
#  'article-00362': 'p55',
#  'article-00363': 'p55',
#  'article-00364': 'p55',
#  'article-00365': 'p55',
#  'article-00366': 'p55',
#  'article-00367': 'p55',
#  'article-00368': 'p55',
#  'article-00369': 'p55',
#  'article-00370': 'p55',
#  'article-00371': 'p55',
#  'article-00372': 'p55',
#  'article-00373': 'p55',
#  'article-00374': 'p55',
#  'article-00375': 'p55',
#  'article-00376': 'p55',
#  'article-00377': 'p55',
#  'article-00378': 'p55',
#  'article-00379': 'p55',
#  'article-00380': 'p55',
#  'article-00381': 'p55',
#  'article-00382': 'p55',
#  'article-00383': 'p55',
#  'article-00384': 'p55',
#  'article-00385': 'p55',
#  'article-00386': 'p55',
#  'article-00387': 'p55',
#  'article-00388': 'p55',
#  'article-00389': 'p55',
#  'article-00390': 'p55',
#  'article-00391': 'p55',
#  'article-00392': 'p55',
#  'article-00393': 'p55',
#  'article-00394': 'p55',
#  'article-00395': 'p55',
#  'article-00396': 'p55',
#  'article-00397': 'p55',
#  'article-00398': 'p55',
#  'article-00399': 'p55',
#  'article-00400': 'p55',
#  'article-00401': 'p55',
#  'article-00402': 'p55',
#  'article-00403': 'p55',
#  'article-00404': 'p55',
#  'article-00405': 'p55',
#  'article-00406': 'p55',
#  'article-00407': 'p55',
#  'article-00408': 'p55',
#  'article-00409': 'p55',
#  'article-00410': 'p55',
#  'article-00411': 'p55',
#  'article-00412': 'p55',
#  'article-00413': 'p55',
#  'article-00414': 'p55',
#  'article-00415': 'p55',
#  'article-00416': 'p55',
#  'article-00417': 'p55',
#  'article-00418': 'p55',
#  'article-00419': 'p55',
#  'article-00420': 'p55',
#  'article-00421': 'p55',
#  'article-00422': 'p55',
#  'article-00423': 'p55',
#  'article-00424': 'p55',
#  'article-00425': 'p55',
#  'article-00426': 'p55',
#  'article-00427': 'p55',
#  'article-00428': 'p55',
#  'article-00429': 'p55',
#  'article-00430': 'p55',
#  'article-00431': 'p55',
#  'article-00432': 'p55',
#  'article-00433': 'p55',
#  'article-00434': 'p55',
#  'article-00435': 'p55',
#  'article-00436': 'p55',
#  'article-00437': 'p55',
#  'article-00438': 'p55',
#  'article-00439': 'p55',
#  'article-00440': 'p55',
#  'article-00441': 'p55',
#  'article-00442': 'p55',
#  'article-00443': 'p55',
#  'article-00444': 'p55',
#  'article-00445': 'p55',
#  'article-00446': 'p55',
#  'article-00447': 'p55',
#  'article-00448': 'p55',
#  'article-00449': 'p55',
#  'article-00450': 'p55',
#  'article-00451': 'p55',
#  'article-00452': 'p55',
#  'article-00453': 'p55',
#  'article-00454': 'p55',
#  'article-00455': 'p55',
#  'article-00456': 'p55',
#  'article-00457': 'p55',
#  'article-00458': 'p55',
#  'article-00459': 'p55',
#  'article-00460': 'p55',
#  'article-00461': 'p55',
#  'article-00462': 'p55',
#  'article-00463': 'p55',
#  'article-00464': 'p55',
#  'article-00465': 'p55',
#  'article-00466': 'p55',
#  'article-00467': 'p55',
#  'article-00468': 'p55',
#  'article-00469': 'p55',
#  'article-00470': 'p55',
#  'article-00471': 'p55',
#  'article-00472': 'p55',
#  'article-00473': 'p55',
#  'article-00474': 'p55',
#  'article-00475': 'p55',
#  'article-00476': 'p55',
#  'article-00477': 'p55',
#  'article-00478': 'p55',
#  'article-00479': 'p55',
#  'article-00480': 'p55',
#  'article-00481': 'p55',
#  'article-00482': 'p55',
#  'article-00483': 'p55',
#  'article-00484': 'p55',
#  'article-00485': 'p55',
#  'article-00486': 'p55',
#  'article-00487': 'p55',
#  'article-00488': 'p55',
#  'article-00489': 'p55',
#  'article-00490': 'p55',
#  'article-00491': 'p55',
#  'article-00492': 'p55',
#  'article-00493': 'p55',
#  'article-00494': 'p55',
#  'article-00495': 'p55',
#  'article-00496': 'p55',
#  'article-00497': 'p55',
#  'article-00498': 'p55',
#  'article-00499': 'p55',
#  'article-00500': 'p55',
#  'article-00501': 'p55',
#  'article-00502': 'p55',
#  'article-00503': 'p55',
#  'article-00504': 'p55',
#  'article-00505': 'p55',
#  'article-00506': 'p55',
#  'article-00507': 'p55',
#  'article-00508': 'p55',
#  'article-00509': 'p55',
#  'article-00510': 'p55',
#  'article-00511': 'p55',
#  'article-00512': 'p55',
#  'article-00513': 'p55',
#  'article-00514': 'p55',
#  'article-00515': 'p55',
#  'article-00516': 'p55',
#  'article-00517': 'p55',
#  'article-00518': 'p55',
#  'article-00519': 'p55',
#  'article-00520': 'p55',
#  'article-00521': 'p55',
#  'article-00522': 'p55',
#  'article-00523': 'p55',
#  'article-00524': 'p55',
#  'article-00525': 'p55',
#  'article-00526': 'p55',
#  'article-00527': 'p55',
#  'article-00528': 'p55',
#  'article-00529': 'p55',
#  'article-00530': 'p55',
#  'article-00531': 'p55',
#  'article-00532': 'p55',
#  'article-00533': 'p55',
#  'article-00534': 'p55',
#  'article-00535': 'p55',
#  'article-00536': 'p55',
#  'article-00537': 'p55',
#  'article-00538': 'p55',
#  'article-00539': 'p55',
#  'article-00540': 'p55',
#  'article-00541': 'p55',
#  'article-00542': 'p55',
#  'article-00543': 'p55',
#  'article-00544': 'p55',
#  'article-00545': 'p55',
#  'article-00546': 'p55',
#  'article-00547': 'p55',
#  'article-00548': 'p55',
#  'article-00549': 'p55',
#  'article-00550': 'p55',
#  'article-00551': 'p55',
#  'article-00552': 'p55',
#  'article-00553': 'p55',
#  'article-00554': 'p55',
#  'article-00555': 'p55',
#  'article-00556': 'p55',
#  'article-00557': 'p55',
#  'article-00558': 'p55',
#  'article-00559': 'p55',
#  'article-00560': 'p55',
#  'article-00561': 'p55',
#  'article-00562': 'p55',
#  'article-00563': 'p55',
#  'article-00564': 'p55',
#  'article-00565': 'p55',
#  'article-00566': 'p55',
#  'article-00567': 'p55',
#  'article-00568': 'p55',
#  'article-00569': 'p55',
#  'article-00570': 'p55',
#  'article-00571': 'p55',
#  'article-00572': 'p55',
#  'article-00573': 'p55',
#  'article-00574': 'p55',
#  'article-00575': 'p55',
#  'article-00576': 'p55',
#  'article-00577': 'p55',
#  'article-00578': 'p55',
#  'article-00579': 'p55',
#  'article-00580': 'p55',
#  'article-00581': 'p55',
#  'article-00582': 'p55',
#  'article-00583': 'p55',
#  'article-00584': 'p55',
#  'article-00585': 'p55',
#  'article-00586': 'p55',
#  'article-00587': 'p55',
#  'article-00588': 'p55',
#  'article-00589': 'p55',
#  'article-00590': 'p55',
#  'article-00591': 'p55',
#  'article-00592': 'p55',
#  'article-00593': 'p55',
#  'article-00594': 'p55',
#  'article-00595': 'p55',
#  'article-00596': 'p55',
#  'article-00597': 'p55',
#  'article-00598': 'p55',
#  'article-00599': 'p55',
#  'article-00600': 'p55',
#  'article-00601': 'p55',
#  'article-00602': 'p55',
#  'article-00603': 'p55',
#  'article-00604': 'p55',
#  'article-00605': 'p55',
#  'article-00606': 'p55',
#  'article-00607': 'p55',
#  'article-00608': 'p55',
#  'article-00609': 'p55',
#  'article-00610': 'p55',
#  'article-00611': 'p55',
#  'article-00612': 'p55',
#  'article-00613': 'p55',
#  'article-00614': 'p55',
#  'article-00615': 'p55',
#  'article-00616': 'p55',
#  'article-00617': 'p55',
#  'article-00618': 'p55',
#  'article-00619': 'p55',
#  'article-00620': 'p55',
#  'article-00621': 'p55',
#  'article-00622': 'p55',
#  'article-00623': 'p55',
#  'article-00624': 'p55',
#  'article-00625': 'p55',
#  'article-00626': 'p55',
#  'article-00627': 'p55',
#  'article-00628': 'p55',
#  'article-00629': 'p55',
#  'article-00630': 'p55',
#  'article-00631': 'p55',
#  'article-00632': 'p55',
#  'article-00633': 'p55',
#  'article-00634': 'p55',
#  'article-00635': 'p55',
#  'article-00636': 'p55',
#  'article-00637': 'p55',
#  'article-00638': 'p55',
#  'article-00639': 'p55',
#  'article-00640': 'p55',
#  'article-00641': 'p55',
#  'article-00642': 'p55',
#  'article-00643': 'p55',
#  'article-00644': 'p55',
#  'article-00645': 'p55',
#  'article-00646': 'p55',
#  'article-00647': 'p55',
#  'article-00648': 'p55',
#  'article-00649': 'p55',
#  'article-00650': 'p55',
#  'article-00651': 'p55',
#  'article-00652': 'p55',
#  'article-00653': 'p55',
#  'article-00654': 'p55',
#  'article-00655': 'p55',
#  'article-00656': 'p55',
#  'article-00657': 'p55',
#  'article-00658': 'p55',
#  'article-00659': 'p55',
#  'article-00660': 'p55',
#  'article-00661': 'p55',
#  'article-00662': 'p55',
#  'article-00663': 'p55',
#  'article-00664': 'p55',
#  'article-00665': 'p55',
#  'article-00666': 'p55',
#  'article-00667': 'p55',
#  'article-00668': 'p55',
#  'article-00669': 'p55',
#  'article-00670': 'p55',
#  'article-00671': 'p55',
#  'article-00672': 'p55',
#  'article-00673': 'p55',
#  'article-00674': 'p55',
#  'article-00675': 'p55',
#  'article-00676': 'p55',
#  'article-00677': 'p55',
#  'article-00678': 'p55',
#  'article-00679': 'p55',
#  'article-00680': 'p55',
#  'article-00681': 'p55',
#  'article-00682': 'p55',
#  'article-00683': 'p55',
#  'article-00684': 'p55',
#  'article-00685': 'p55',
#  'article-00686': 'p55',
#  'article-00687': 'p55',
#  'article-00688': 'p55',
#  'article-00689': 'p55',
#  'article-00690': 'p55',
#  'article-00691': 'p55',
#  'article-00692': 'p55',
#  'article-00693': 'p55',
#  'article-00694': 'p55',
#  'article-00695': 'p55',
#  'article-00696': 'p55',
#  'article-00697': 'p55',
#  'article-00698': 'p55',
#  'article-00699': 'p55',
#  'article-00700': 'p55',
#  'article-00701': 'p55',
#  'article-00702': 'p55',
#  'article-00703': 'p55',
#  'article-00704': 'p55',
#  'article-00705': 'p55',
#  'article-00706': 'p55',
#  'article-00707': 'p55',
#  'article-00708': 'p55',
#  'article-00709': 'p55',
#  'article-00710': 'p55',
#  'article-00711': 'p55',
#  'article-00712': 'p55',
#  'article-00713': 'p55',
#  'article-00714': 'p55',
#  'article-00715': 'p55',
#  'article-00716': 'p55',
#  'article-00717': 'p55',
#  'article-00718': 'p55',
#  'article-00719': 'p55',
#  'article-00720': 'p55',
#  'article-00721': 'p55',
#  'article-00722': 'p55',
#  'article-00723': 'p55',
#  'article-00724': 'p55',
#  'article-00725': 'p55',
#  'article-00726': 'p55',
#  'article-00727': 'p55',
#  'article-00728': 'p55',
#  'article-00729': 'p55',
#  'article-00730': 'p55',
#  'article-00731': 'p55',
#  'article-00732': 'p55',
#  'article-00733': 'p55',
#  'article-00734': 'p55',
#  'article-00735': 'p55',
#  'article-00736': 'p55',
#  'article-00737': 'p55',
#  'article-00738': 'p55',
#  'article-00739': 'p55',
#  'article-00740': 'p55',
#  'article-00741': 'p55',
#  'article-00742': 'p55',
#  'article-00743': 'p55',
#  'article-00744': 'p55',
#  'article-00745': 'p55',
#  'article-00746': 'p55',
#  'article-00747': 'p55',
#  'article-00748': 'p55',
#  'article-00749': 'p55',
#  'article-00750': 'p55',
#  'article-00751': 'p55',
#  'article-00752': 'p55',
#  'article-00753': 'p55',
#  'article-00754': 'p55',
#  'article-00755': 'p55',
#  'article-00756': 'p55',
#  'article-00757': 'p55',
#  'article-00758': 'p55',
#  'article-00759': 'p55',
#  'article-00760': 'p55',
#  'article-00761': 'p55',
#  'article-00762': 'p55',
#  'article-00763': 'p55',
#  'article-00764': 'p55',
#  'article-00765': 'p55',
#  'article-00766': 'p55',
#  'article-00767': 'p55',
#  'article-00768': 'p55',
#  'article-00769': 'p55',
#  'article-00770': 'p55',
#  'article-00771': 'p55',
#  'article-00772': 'p55',
#  'article-00773': 'p55',
#  'article-00774': 'p55',
#  'article-00775': 'p55',
#  'article-00776': 'p55',
#  'article-00777': 'p55',
#  'article-00778': 'p55',
#  'article-00779': 'p55',
#  'article-00780': 'p55',
#  'article-00781': 'p55',
#  'article-00782': 'p55',
#  'article-00783': 'p55',
#  'article-00784': 'p55',
#  'article-00785': 'p55',
#  'article-00786': 'p55',
#  'article-00787': 'p55',
#  'article-00788': 'p55',
#  'article-00789': 'p55',
#  'article-00790': 'p55',
#  'article-00791': 'p55',
#  'article-00792': 'p55',
#  'article-00793': 'p55',
#  'article-00794': 'p55',
#  'article-00795': 'p55',
#  'article-00796': 'p55',
#  'article-00797': 'p55',
#  'article-00798': 'p55',
#  'article-00799': 'p55',
#  'article-00800': 'p55',
#  'article-00801': 'p55',
#  'article-00802': 'p55',
#  'article-00803': 'p55',
#  'article-00804': 'p55',
#  'article-00805': 'p55',
#  'article-00806': 'p55',
#  'article-00807': 'p55',
#  'article-00808': 'p55',
#  'article-00809': 'p55',
#  'article-00810': 'p55',
#  'article-00811': 'p55',
#  'article-00812': 'p55',
#  'article-00813': 'p55',
#  'article-00814': 'p55',
#  'article-00815': 'p55',
#  'article-00816': 'p55',
#  'article-00817': 'p55',
#  'article-00818': 'p55',
#  'article-00819': 'p55',
#  'article-00820': 'p55',
#  'article-00821': 'p55',
#  'article-00822': 'p55',
#  'article-00823': 'p55',
#  'article-00824': 'p55',
#  'article-00825': 'p55',
#  'article-00826': 'p55',
#  'article-00827': 'p55',
#  'article-00828': 'p55',
#  'article-00829': 'p55',
#  'article-00830': 'p55',
#  'article-00831': 'p55',
#  'article-00832': 'p55',
#  'article-00833': 'p55',
#  'article-00834': 'p55',
#  'article-00835': 'p55',
#  'article-00836': 'p55',
#  'article-00837': 'p55',
#  'article-00838': 'p55',
#  'article-00839': 'p55',
#  'article-00840': 'p55',
#  'article-00841': 'p55',
#  'article-00842': 'p55',
#  'article-00843': 'p55',
#  'article-00844': 'p55',
#  'article-00845': 'p55',
#  'article-00846': 'p55',
#  'article-00847': 'p55',
#  'article-00848': 'p55',
#  'article-00849': 'p55',
#  'article-00850': 'p55',
#  'article-00851': 'p55',
#  'article-00852': 'p55',
#  'article-00853': 'p55',
#  'article-00854': 'p55',
#  'article-00855': 'p55',
#  'article-00856': 'p55',
#  'article-00857': 'p55',
#  'article-00858': 'p55',
#  'article-00859': 'p55',
#  'article-00860': 'p55',
#  'article-00861': 'p55',
#  'article-00862': 'p55',
#  'article-00863': 'p55',
#  'article-00864': 'p55',
#  'article-00865': 'p55',
#  'article-00866': 'p55',
#  'article-00867': 'p55',
#  'article-00868': 'p55',
#  'article-00869': 'p55',
#  'article-00870': 'p55',
#  'article-00871': 'p55',
#  'article-00872': 'p55',
#  'article-00873': 'p55',
#  'article-00874': 'p55',
#  'article-00875': 'p55',
#  'article-00876': 'p55',
#  'article-00877': 'p55',
#  'article-00878': 'p55',
#  'article-00879': 'p55',
#  'article-00880': 'p55',
#  'article-00881': 'p55',
#  'article-00882': 'p55',
#  'article-00883': 'p55',
#  'article-00884': 'p55',
#  'article-00885': 'p55',
#  'article-00886': 'p55',
#  'article-00887': 'p55',
#  'article-00888': 'p55',
#  'article-00889': 'p55',
#  'article-00890': 'p55',
#  'article-00891': 'p55',
#  'article-00892': 'p55',
#  'article-00893': 'p55',
#  'article-00894': 'p55',
#  'article-00895': 'p55',
#  'article-00896': 'p55',
#  'article-00897': 'p55',
#  'article-00898': 'p55',
#  'article-00899': 'p55',
#  'article-00900': 'p55',
#  'article-00901': 'p55',
#  'article-00902': 'p55',
#  'article-00903': 'p55',
#  'article-00904': 'p55',
#  'article-00905': 'p55',
#  'article-00906': 'p55',
#  'article-00907': 'p55',
#  'article-00908': 'p55',
#  'article-00909': 'p55',
#  'article-00910': 'p55',
#  'article-00911': 'p55',
#  'article-00912': 'p55',
#  'article-00913': 'p55',
#  'article-00914': 'p55',
#  'article-00915': 'p55',
#  'article-00916': 'p55',
#  'article-00917': 'p55',
#  'article-00918': 'p55',
#  'article-00919': 'p55',
#  'article-00920': 'p55',
#  'article-00921': 'p55',
#  'article-00922': 'p55',
#  'article-00923': 'p55',
#  'article-00924': 'p55',
#  'article-00925': 'p55',
#  'article-00926': 'p55',
#  'article-00927': 'p55',
#  'article-00928': 'p55',
#  'article-00929': 'p55',
#  'article-00930': 'p55',
#  'article-00931': 'p55',
#  'article-00932': 'p55',
#  'article-00933': 'p55',
#  'article-00934': 'p55',
#  'article-00935': 'p55',
#  'article-00936': 'p55',
#  'article-00937': 'p55',
#  'article-00938': 'p55',
#  'article-00939': 'p55',
#  'article-00940': 'p55',
#  'article-00941': 'p55',
#  'article-00942': 'p55',
#  'article-00943': 'p55',
#  'article-00944': 'p55',
#  'article-00945': 'p55',
#  'article-00946': 'p55',
#  'article-00947': 'p55',
#  'article-00948': 'p55',
#  'article-00949': 'p55',
#  'article-00950': 'p55',
#  'article-00951': 'p55',
#  'article-00952': 'p55',
#  'article-00953': 'p55',
#  'article-00954': 'p55',
#  'article-00955': 'p55',
#  'article-00956': 'p55',
#  'article-00957': 'p55',
#  'article-00958': 'p55',
#  'article-00959': 'p55',
#  'article-00960': 'p55',
#  'article-00961': 'p55',
#  'article-00962': 'p55',
#  'article-00963': 'p55',
#  'article-00964': 'p55',
#  'article-00965': 'p55',
#  'article-00966': 'p55',
#  'article-00967': 'p55',
#  'article-00968': 'p55',
#  'article-00969': 'p55',
#  'article-00970': 'p55',
#  'article-00971': 'p55',
#  'article-00972': 'p55',
#  'article-00973': 'p55',
#  'article-00974': 'p55',
#  'article-00975': 'p55',
#  'article-00976': 'p55',
#  'article-00977': 'p55',
#  'article-00978': 'p55',
#  'article-00979': 'p55',
#  'article-00980': 'p55',
#  'article-00981': 'p55',
#  'article-00982': 'p55',
#  'article-00983': 'p55',
#  'article-00984': 'p55',
#  'article-00985': 'p55',
#  'article-00986': 'p55',
#  'article-00987': 'p55',
#  'article-00988': 'p55',
#  'article-00989': 'p55',
#  'article-00990': 'p55',
#  'article-00991': 'p55',
#  'article-00992': 'p55',
#  'article-00993': 'p55',
#  'article-00994': 'p55',
#  'article-00995': 'p55',
#  'article-00996': 'p55',
#  'article-00997': 'p55',
#  'article-00998': 'p55',
#  'article-00999': 'p55',
#  ...}
